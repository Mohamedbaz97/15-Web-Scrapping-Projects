# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
option1.add_argument('--disable-popup-blocking')
option1.add_argument('--disable-notifications')
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
driver.implicitly_wait(10)
class wait_for_more_than_n_elements(object):
    def __init__(self, locator, count):
        self.locator = locator
        self.count = count

    def __call__(self, driver):
        try:
            count = len(EC._find_elements(driver, self.locator))
            return count >= self.count
        except StaleElementReferenceException:
            return False
def scroll_to_bottom(driver):

    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        # Sleep and Scroll
        driver.implicitly_wait(15)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        driver.implicitly_wait(15)
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        time.sleep(20)
        return
def pageBottom(driver):
        bottom=False
        a=0
        while not bottom:
            new_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script(f"window.scrollTo(0, {a});")
            if a > new_height:
                bottom=True
            a+=3
for i in range(1,50):
    url = 'https://www.autokazak.com/buy-cars?page='+str(i)
    
    driver.get(url)
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, "html.parser")

    for link in soup.findAll("div", class_="ad-specification"):
                try:
                    Name=link.find('div', class_='specification-section').text
                    print(Name)
                except Exception as e:
                    Name = None
                try:      
                    Location=link.find('div', attrs={'class':'location'}).text
                    print(Location)
                except Exception as e:
                    Location = None
                try:  
                    Price=link.find('div', attrs={'class':'ad-vehicle-price'}).text
                    print(Price)
                except Exception as e:
                    Price = None
                try:  
                    Mileage=link.find('div', attrs={'class':'ad-vehicle-mileage'}).text
                    print(Mileage)
                except Exception as e:
                    Mileage = None
                try:  
                    Engine=link.find('div', attrs={'class':'ad-vehicle-engine'}).text
                    print(Engine)
                except Exception as e:
                    Engine = None
                try:  
                    Transmission=link.find('div', attrs={'class':'transmission'}).text
                    print(Transmission)
                except Exception as e:
                    Transmission = None
                try:  
                    Description=link.find('div', attrs={'class':"md-hidden sort-ad-description"}).text
                    print(Description)
                except Exception as e:
                    Description = None
                
            
                if (Name == None)  and (Location==None) and (Price == None) and (Mileage == None) and (Engine == None) and(Transmission==None) and (Description == None):
                    continue
                else:
                    with open('AutoKazaka.csv','a', encoding='utf-8', newline='') as file:
                        writer=csv.writer(file)
                        file_is_empty = os.stat('AutoKazaka.csv').st_size == 0
                        if file_is_empty:
                              writer.writerow(['Name','Location','Price','Mileage','Engine','Transmission','Description'])

                        writer.writerow([Name,Location,Price,Mileage,Engine,Transmission,Description,])
file.close()
# Out:
# 2017 McLaren 540CAstana
# Astana
# PriceNEGOTIABLE
# Mileage41,000 km
# 3.8 L (Petrol)Automatic
# Automatic
# ...

# %%
#soup
