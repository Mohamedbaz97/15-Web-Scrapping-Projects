# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
def pageBottom(driver):
        bottom=False
        a=0
        while not bottom:
            new_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script(f"window.scrollTo(0, {a});")
            if a > new_height:
                bottom=True
            a+=3
driver.implicitly_wait(10)
url = 'https://www.cars24.com/ae/buy-used-cars-dubai?sf=city:DU_DUBAI'
driver.get(url)
pageBottom(driver)
time.sleep(2)
soup = BeautifulSoup(driver.page_source, "html.parser")
          
# for link in soup.findAll("div", class_=re.compile("_3IIl_ _1xLfH", re.I)):
#             try:
#                 name=link.find('h3', class_='RZ4T7').text
#             except Exception as e:
#                 name = None
#             try:      
#                 price=link.find('span', attrs={'class':'_7yds2'}).text
#             except Exception as e:
#                 price = None
#             try:
#                 loc=link.find('div', attrs={'class':'_3-ZAV'}).text
#             except Exception as e:
#                 loc = None
#             try:
#                 year=link.find('p', attrs={'class':'_1i1E6'}).text
#             except Exception as e:
#                 year = None
           
        
#             try:
#                 Decription=link.find('ul', attrs={'class':'_3ZoHn'}).text
#             except Exception as e:
#                 Decription = None
           
#             for link1 in link.findAll('a'):
#                 links=link1.get('href')
#             if (name == None) and (price == None) and (loc == None) and  (year==None) and (Decription==None):
#                     continue
#             else:
#                 with open('Cars24.csv','a', encoding='utf-8', newline='') as file:
#                     writer=csv.writer(file)
#                     file_is_empty = os.stat('Cars24.csv').st_size == 0
#                     if file_is_empty:
#                           writer.writerow(['name','year','price','loc','Decription'])

#                     writer.writerow([name,year,price,loc,Decription])
# file.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[1], line 40
#      38 url = 'https://www.cars24.com/ae/buy-used-cars-dubai?sf=city:DU_DUBAI'
#      39 driver.get(url)
# ---> 40 pageBottom(driver)
#      41 time.sleep(2)
#      42 soup = BeautifulSoup(driver.page_source, "html.parser")
#
# Cell In[1], line 33, in pageBottom(driver)
#      31 while not bottom:
#      32     new_height = driver.execute_script("return document.body.scrollHeight")
# ---> 33     driver.execute_script(f"window.scrollTo(0, {a});")
#      34     if a > new_height:
#      35         bottom=True
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:404, in WebDriver.execute_script(self, script, *args)
#     401 converted_args = list(args)
#     402 command = Command.W3C_EXECUTE_SCRIPT
# ...
