# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
option1.add_argument('--disable-popup-blocking')
option1.add_argument('--disable-notifications')
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
driver.implicitly_wait(10)
class wait_for_more_than_n_elements(object):
    def __init__(self, locator, count):
        self.locator = locator
        self.count = count

    def __call__(self, driver):
        try:
            count = len(EC._find_elements(driver, self.locator))
            return count >= self.count
        except StaleElementReferenceException:
            return False
def scroll_to_bottom(driver):

    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        # Sleep and Scroll
        driver.implicitly_wait(15)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        driver.implicitly_wait(15)
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        time.sleep(20)
        return
def pageBottom(driver):
        bottom=False
        a=0
        while not bottom:
            new_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script(f"window.scrollTo(0, {a});")
            if a > new_height:
                bottom=True
            a+=3
for i in range(0,17):
    url = 'https://www.kavak.com/ae/preowned/?page='+str(i)
    
    driver.get(url)
    pageBottom(driver)
    
#     total_height = int(driver.execute_script("return document.body.scrollHeight"))
#     for i in range(1, total_height, 5):
#         driver.execute_script("window.scrollTo(0, {});".format(i))   
    #scroll_to_bottom(driver)
    driver.implicitly_wait(10)
    time.sleep(2)
#     soup = BeautifulSoup(driver.page_source, "html.parser")
#     for link in soup.findAll("a", class_="card card-column"):
#         try:
#             name=link.find('h3', class_='card-title').text
#         except Exception as e:
#             name = None
#         try:      
#             price=link.find('span', attrs={'class':'normal'}).text
#         except Exception as e:
#             price = None
#         try:
#             Decription=link.find('p', attrs={'class':'card-details'}).text
#         except Exception as e:
#             Decription = None
#         try:
#             Links=link.find('div', class_='card-img').get('src')
#         except Links as e:
#             Links = None
#         if (name == None) and (price == None) and (Links == None) and (Decription == None) :
#             continue
#         else:
#             with open('Kavak.csv','a', encoding='utf-8', newline='') as file:
#                 writer=csv.writer(file)
#                 file_is_empty = os.stat('Kavak.csv').st_size == 0
#                 if file_is_empty:
#                     writer.writerow(['name','price','Decription','Links'])
#                 writer.writerow([name,price,Decription,Links])
# file.close()

# %%
soup
# Out:
# <html dir="ltr" lang="en-AE"><head><script async="" src="https://www.clarity.ms/s/0.7.13/clarity.js"></script><script async="" data-id="CK09OP3C77UDFRIV1AJG" src="https://analytics.tiktok.com/i18n/pixel/static/main.MTEyYzFhMzhjMA.js" type="text/javascript"></script><script async="" src="https://www.clarity.ms/tag/uet/187043875"></script><script async="true" crossorigin="anonymous" src="https://tr.snapchat.com/config/com/7112cb02-3172-473c-95c2-5b4471ebc4da.js?v=3.4.11-2310110039"></script><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VFHE5QZLSP&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/122188195103418?v=2.9.134&amp;r=stable&amp;domain=www.kavak.com"></script><script async="" 
# ...
