# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
option1.add_argument('--disable-popup-blocking')
option1.add_argument('--disable-notifications')
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
driver.implicitly_wait(10)
class wait_for_more_than_n_elements(object):
    def __init__(self, locator, count):
        self.locator = locator
        self.count = count

    def __call__(self, driver):
        try:
            count = len(EC._find_elements(driver, self.locator))
            return count >= self.count
        except StaleElementReferenceException:
            return False
def scroll_to_bottom(driver):

    old_position = 0
    new_position = None

    while new_position != old_position:
        # Get old scroll position
        old_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        # Sleep and Scroll
        driver.implicitly_wait(15)
        driver.execute_script((
                "var scrollingElement = (document.scrollingElement ||"
                " document.body);scrollingElement.scrollTop ="
                " scrollingElement.scrollHeight;"))
        driver.implicitly_wait(15)
        # Get new position
        new_position = driver.execute_script(
                ("return (window.pageYOffset !== undefined) ?"
                 " window.pageYOffset : (document.documentElement ||"
                 " document.body.parentNode || document.body);"))
        time.sleep(20)
        return
def pageBottom(driver):
        bottom=False
        a=0
        while not bottom:
            new_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script(f"window.scrollTo(0, {a});")
            if a > new_height:
                bottom=True
            a+=3

for i in range(1,3276):
        url = 'https://www.ouedkniss.com/automobiles/'+str(i)
        driver.get(url)
        scroll_to_bottom(driver)
        time.sleep(2)
        
        driver.implicitly_wait(15)
        soup = BeautifulSoup(driver.page_source, "html.parser")
             
        for link in soup.findAll("div", class_=re.compile("col-sm-6 col-md-4 col-lg-3 col-12", re.I)):
                try:
                    Location=link.find('div', class_='mb-1 d-flex flex-column flex-gap-1 line-height-1').text
                    print(Location)
                except Exception as e:
                    Location = None
                try:
                    Name=link.find('h2', class_='mb-1').text
                    print(Name)
                except Exception as e:
                    Name = None
                try:      
                    Price=link.find('div', attrs={'class':'d-flex flex-wrap flex-gap-1 align-center'}).text
                    print(Price)
                except Exception as e:
                    Price = None
                try:
                    Capacity=link.find('div', attrs={'class':'col py-0 px-0 my-1'}).text
                    print(Capacity)
                except Exception as e:
                    Capacity = None
#                 try:
#                     transmission=link.find('div', attrs={'class':'transmission'}).text
            
#                 except Exception as e:
#                     transmission = None
#                 try:
#                     mileage=link.find('div', attrs={'class':'ad-vehicle-mileage'}).text
                   
#                 except Exception as e:
#                     mileage = None
#                 try:
#                     Desc = link.find(name='div', attrs={'class': "md-hidden sort-ad-description"}).text
#                 except:
#                     Desc=None
#                 try:
#                     url_path = link.div.a.get('href')
#                     urlpath = "https://www.cardjibouti.com/"+url_path
#                 except Exception as e:
#                     urlpath=None
                     
#                 if (Name==None) and (Location == None) and (Price == None) and (Capacity==None) :
#                     continue
#                 else:
#                     with open('ouedkniss.csv','a', encoding='utf-8', newline='') as file:
#                         writer=csv.writer(file)
#                         file_is_empty = os.stat('ouedkniss.csv').st_size == 0
#                         if file_is_empty:
#                               writer.writerow(['Name','Location','price',"Capacity"])

#                         writer.writerow([Name,Location,Price,Capacity])
#         file.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[4], line 80
#      78 url = 'https://www.ouedkniss.com/automobiles/'+str(i)
#      79 driver.get(url)
# ---> 80 scroll_to_bottom(driver)
#      81 time.sleep(2)
#      83 driver.implicitly_wait(15)
#
# Cell In[4], line 49, in scroll_to_bottom(driver)
#      45 new_position = None
#      47 while new_position != old_position:
#      48     # Get old scroll position
# ---> 49     old_position = driver.execute_script(
#      50             ("return (window.pageYOffset !== undefined) ?"
#      51              " window.pageYOffset : (document.documentElement ||"
#      52              " document.body.parentNode || document.body);"))
#      53     # Sleep and Scroll
#      54     driver.implicitly_wait(15)
#
# ...

# %%
print(Desc)
# Out:
# None
