# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
option1.add_argument('--disable-popup-blocking')
option1.add_argument('--disable-notifications')
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
driver.implicitly_wait(10)

for i in range(1,84):
        url = 'https://cars.et.cari.africa/cars/new-car-in-ethiopia/'+str(i)
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, "html.parser")
             
        for link in soup.findAll("div", class_="item"):
                try:
                    Location=link.find('div', class_='itemCity').text
                    print(Location)
                except Exception as e:
                    Location = None
                try:
                    Name=link.find('h3', class_='itemTitle').text
                    print(Name)
                except Exception as e:
                    Name = None
                try:      
                    Price=link.find('div', attrs={'class':'price'}).text
                    print(Price)
                except Exception as e:
                    Price = None
                try:
                    Details=link.find('div', attrs={'class':'itemDetail'}).text
                    print(Details)
                except Exception as e:
                    Details = None
                try:
                    Desc = link.find(name='div', attrs={'class': "itemDesc"}).text
                except:
                    Desc=None                     
                if (Name==None) and (Location == None) and (Price == None) and (Details==None) and (Desc==None):
                    continue
                else:
                    with open('carethiopia.csv','a', encoding='utf-8', newline='') as file:
                        writer=csv.writer(file)
                        file_is_empty = os.stat('carethiopia.csv').st_size == 0
                        if file_is_empty:
                              writer.writerow(['Name','Location','Price',"Details",'Desc'])

                        writer.writerow([Name,Location,Price,Details,Desc])
        file.close()
# Out:
# Addis Ababa
# Hyundai Grand Starex 2021 Brand New Full Option Van Car for Sale
# Price : 5,100,000.00 ETB Negotiable Posted: 56 seconds ago Brand : Hyundai Condition : New Model : Grand Starex Transmission : Automatic Manufacture Year : 2021 Car Type : Minibus and Van Steering ...Yesterday 16:10 - engocha.com
# Addis Ababa
# Jetour X70 plus 2024
# Price : 4,500,000.00 ETB Fixed Posted: 2 minutes ago Brand : CHERY Condition : New Model : Jetour X70+ Transmission : Automatic Manufacture Year : 2023 Car Type : SUV (Sports Utility Vehicle) ...Yesterday 23:13 - engocha.com
# Addis Ababa
# Hilux invincible Double cab 2022
# Price : 13,500,000.00 ETB Fixed Posted: 1 hour ago Brand : Toyota Condition : New Transmission : Automatic Manufacture Year : 2022 Car Type : Pickup Steering Side : Original Left Fuel : Diesel ...Yesterday 11:02 - engocha.com
# Addis Ababa
# Toyota Hiace HighRoof 2023 Brand New Minibus Car for Sale in Ethiopia
# ...

# %%
print(Desc)
# Out:
# Toyota -  Yaris - Automatic - New
