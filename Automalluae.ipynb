# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait       
from selenium.webdriver.common.by import By  
from selenium.webdriver.common.action_chains import ActionChains     
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
import time
import re
import json
import pandas as pd
import numpy as np
import os
from selenium.webdriver.common.keys import Keys

option1=Options()

prefs = {"profile.default_content_setting_values.notifications" : 2}
option1.add_experimental_option("prefs",prefs)
service = Service(executable_path='C:/Users/Nandini Dulam/OneDrive/WebScraping/chromedriver.exe',chrome_options=option1)
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
def pageBottom(driver):
        bottom=False
        a=0
        while not bottom:
            new_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script(f"window.scrollTo(0, {a});")
            if a > new_height:
                bottom=True
            a+=3
driver.implicitly_wait(10)
url = 'https://www.automalluae.com/en/used-cars-shop/'
driver.get(url)
pageBottom(driver)
time.sleep(2)
soup = BeautifulSoup(driver.page_source, "html.parser")
links=[]          
for link in soup.findAll("div", class_=re.compile("ProductCard-module_ProductCard_Wrapper__PAO01", re.I)):
            try:
                name=link.find('div', class_='ProductCard-module_ProductName__-hnY2').text
            except Exception as e:
                name = None
            try:      
                price=link.find('div', attrs={'class':'ProductCard-module_ProductCommercial_EMI__OquRM col-6'}).text
            except Exception as e:
                price = None
                    
        
            try:
                Decription=link.find('div', attrs={'class':'ProductCard-module_ProductDescription__hZQcV'}).text
            except Exception as e:
                Decription = None
           
            for link1 in link.findAll('a'):
                links.append(link1.get('href'))
            #links.to_excel('Links.xlsx', index=False)
            if (name == None) and (price == None) and (loc == None) and  (year==None) and (Decription==None):
                    continue
            else:
                with open('Automall.csv','a', encoding='utf-8', newline='') as file:
                    writer=csv.writer(file)
                    file_is_empty = os.stat('Automall.csv').st_size == 0
                    if file_is_empty:
                          writer.writerow(['name','price','Decription'])

                    writer.writerow([name,price,Decription])
file.close()
